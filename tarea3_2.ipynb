# %% [markdown]
# Grafique en una misma figura la siguiente función junto con su serie de Taylor alrededor de  x=0  truncada al término número 10. ¿Hasta cuál valor de  x  parece ser una buena aproximación?
#
# f(x)=xsin(x)
#
# Use colores y estilos de línea diferentes para cada línea. Escoja un rango de valores de  x  que represente lo que quiera concluir sobre esta aproximación. Incluya una leyenda para facilitar la lectura del gráfico

# %%
# primero importamos las librerias que necesitamos
import matplotlib.pyplot as plt
import numpy as np
import math as mt

#graficamos la función pi usando numpy, primero hacemos un linspace que desde -3pi hasta 3pi y con 100 divisiones del intervalo luego sobre esos puntos graficamos la función seno.
x1 = np.linspace(-3*np.pi,3*np.pi,100)
y1 = np.sin(x1)
s=0

# para la serie de taylor hacemos un for con la serie para el seno en torno a x=0 
for i in range(1,11):
    s=s+(((-1)**(i-1))*(x1**(2*i-1))/(mt.factorial(2*i-1)));

#ahora para plotear primero hacemos las leyendas para sin y para la aproximación


plt.plot(x1, y1, label='$\sin(x)$')
plt.plot(x1, s, label='$aproximación \ \sin(x)$')

plt.legend()
plt.show()
# mostramos el plot y vemos que la apoximación es buena pero para numeros mayores a 7.5 aprox o menores a -7.5 apox la serie de los 10 primeros terminos empieza a ser diferente a la funcion de seno.

# %% [markdown]
# # Calificación: 6.9

# %% [markdown]
# Error pequeño al leer el enunciado, se pedía $x \sin x$ en vez de $\sin x$.
